# %%
import pandas as pd

df = pd.read_csv("C:/Users/LENOVO/placement-dashboard/data/raw/placements.csv")
print(df.head())
print(df.shape)
print(df.dtypes)
print(df.isnull().sum())
print(df.describe())
df.head(10)
# Out:
#    student_id  year      branch  cgpa    company  package_lpa placement_type  \
# 0           1  2023          IT  7.72        TCS        28.86      On-Campus
# 1           2  2024          IT  6.90    Infosys        22.68     Off-Campus
# 2           3  2021         CSE  7.61  Microsoft        24.88     Off-Campus
# 3           4  2023  Mechanical  9.43     Amazon        31.19      On-Campus
# 4           5  2023         ECE  7.72     Amazon        12.30     Off-Campus
#
#    placed                                  skills  backlogs
# 0   False                     Power BI, DSA, Java         0
# 1    True          Communication, AWS, Excel, DSA         0
# 2    True                     Python, Java, React         0
# 3    True  React, Python, Communication, AWS, SQL         1
# 4    True      Communication, Excel, DSA, SQL, ML         0
# (500, 10)
# student_id          int64
# year                int64
# branch             object
# cgpa              float64
# ...
